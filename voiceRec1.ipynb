# %%
import librosa
data, sampling_rate = librosa.load("test.mp3", sr=16000)
data = data.tolist()

# spark_df = spark.createDataFrame([[data]], ["audio_content"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import librosa
#       2 data, sampling_rate = librosa.load("test.mp3", sr=16000)
#       3 data = data.tolist()
#
# ModuleNotFoundError: No module named 'librosa'
