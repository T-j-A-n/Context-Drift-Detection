# %%
import librosa
data, sampling_rate = librosa.load("test.mp3", sr=16000)
data = data.tolist()

# spark_df = spark.createDataFrame([[data]], ["audio_content"])

# %%
import sparknlp
spark = sparknlp.start()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import sparknlp
#       2 spark = sparknlp.start()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sparknlp/__init__.py:19
#      16 import sys
#      17 import threading
# ---> 19 from pyspark.conf import SparkConf
#      20 from pyspark.context import SparkContext
#      21 from pyspark.java_gateway import launch_gateway
#
# ModuleNotFoundError: No module named 'pyspark'
